# %%
import pandas as pd
df=pd.read_csv("C:/Users/pramo/Downloads/movie_data/ratings.csv")
df1=pd.read_csv("C:/Users/pramo/Downloads/movie_data/movies.csv")
df2=pd.read_csv("C:/Users/pramo/Downloads/movie_data/tags.csv")
print(df)
print(df1)
print(df2)
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# ...

# %%
# Count unique values in each column
unique_counts = df.nunique()

# Output the result
print(unique_counts)
# Out:
# userId         610
# movieId       9724
# rating          10
# timestamp    85043
# dtype: int64

# %%
# Merge the datasets on 'movieid'
merged_df = pd.merge(df, df1, on='movieId')

# Display the merged dataset
print(merged_df)
# Out:
#         userId  movieId  rating   timestamp                           title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres
# ...

# %%
# Find the movie with the maximum rating
max_rating_row = merged_df.loc[merged_df['rating'].idxmax()]

print(max_rating_row)
# Out:
# userId                                 1
# movieId                               47
# rating                               5.0
# timestamp                      964983815
# title        Seven (a.k.a. Se7en) (1995)
# genres                  Mystery|Thriller
# Name: 3, dtype: object

# %%
movies_with_rating_5 = merged_df[merged_df['rating'] == 5.0]

print(movies_with_rating_5)
# Out:
#         userId  movieId  rating   timestamp                          title  \
# 3            1       47     5.0   964983815    Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931     Usual Suspects, The (1995)
# 6            1      101     5.0   964980868           Bottle Rocket (1996)
# 8            1      151     5.0   964984041                 Rob Roy (1995)
# 9            1      157     5.0   964984100          Canadian Bacon (1995)
# ...        ...      ...     ...         ...                            ...
# 100814     610   158238     5.0  1479545219           The Nice Guys (2016)
# 100829     610   164179     5.0  1493845631                 Arrival (2016)
# 100832     610   168248     5.0  1493850091  John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                 Get Out (2017)
# 100834     610   168252     5.0  1493846352                   Logan (2017)
#
#                                 genres
# ...

# %%
rating_5_counts = movies_with_rating_5['movieId'].value_counts()

print(rating_5_counts)
# Out:
# movieId
# 318       153
# 296       123
# 356       116
# 2571      109
# 260       104
#          ...
# 668         1
# 581         1
# 496         1
# 347         1
# 156371      1
# Name: count, Length: 2954, dtype: int64

# %%
row = merged_df[merged_df['movieId'] == 318]
print(row)
# Out:
#        userId  movieId  rating   timestamp                             title  \
# 232         2      318     3.0  1445714835  Shawshank Redemption, The (1994)
# 536         5      318     3.0   847434880  Shawshank Redemption, The (1994)
# 703         6      318     5.0   845553200  Shawshank Redemption, The (1994)
# 1051        8      318     5.0   839463489  Shawshank Redemption, The (1994)
# 1271       11      318     4.0   902155070  Shawshank Redemption, The (1994)
# ...       ...      ...     ...         ...                               ...
# 97424     606      318     3.5  1171927228  Shawshank Redemption, The (1994)
# 98498     607      318     5.0   963080679  Shawshank Redemption, The (1994)
# 98727     608      318     4.5  1147210910  Shawshank Redemption, The (1994)
# 99511     609      318     4.0   847220907  Shawshank Redemption, The (1994)
# 99554     610      318     3.0  1479541963  Shawshank Redemption, The (1994)
#
#             genres
# 232    Crime|Drama
# ...

# %%
moviename = merged_df[merged_df['title'] == 'Matrix, The (1999)']
print(moviename)
# Out:
#        userId  movieId  rating   timestamp               title  \
# 166         1     2571     5.0   964981888  Matrix, The (1999)
# 442         4     2571     1.0   945173385  Matrix, The (1999)
# 1130       10     2571     0.5  1455356378  Matrix, The (1999)
# 1367       13     2571     5.0   987457007  Matrix, The (1999)
# 1475       15     2571     4.0  1510571744  Matrix, The (1999)
# ...       ...      ...     ...         ...                 ...
# 96689     603     2571     5.0   963177606  Matrix, The (1999)
# 97791     606     2571     5.0  1171325929  Matrix, The (1999)
# 98603     607     2571     5.0   963080047  Matrix, The (1999)
# 99065     608     2571     5.0  1117162423  Matrix, The (1999)
# 99684     610     2571     5.0  1479545822  Matrix, The (1999)
#
#                        genres
# 166    Action|Sci-Fi|Thriller
# 442    Action|Sci-Fi|Thriller
# 1130   Action|Sci-Fi|Thriller
# 1367   Action|Sci-Fi|Thriller
# 1475   Action|Sci-Fi|Thriller
# ...

# %%
merged_df1 = pd.merge(df1, df2, on='movieId')

print(merged_df1)
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
matrix = merged_df1[merged_df1['movieId'] == 2571]
print(matrix)
# Out:
#       movieId               title                  genres  userId  \
# 1313     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1314     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1315     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
# 1316     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 1317     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#                      tag   timestamp
# 1313        martial arts  1457842912
# 1314              sci-fi  1457842899
# 1315  alternate universe  1137204991
# 1316          philosophy  1424141098
# 1317    post apocalyptic  1424141101

# %%
rating = merged_df[merged_df['title']=='Terminator 2: Judgment Day (1991)']
print(rating)
print(rating['rating'].mean())
# Out:
#        userId  movieId  rating   timestamp                              title  \
# 552         5      589     3.0   847435258  Terminator 2: Judgment Day (1991)
# 806         6      589     3.0   845553317  Terminator 2: Judgment Day (1991)
# 886         7      589     2.5  1106635940  Terminator 2: Judgment Day (1991)
# 1286       11      589     4.0   902154266  Terminator 2: Judgment Day (1991)
# 1449       15      589     5.0  1510572012  Terminator 2: Judgment Day (1991)
# ...       ...      ...     ...         ...                                ...
# 97461     606      589     3.5  1171325855  Terminator 2: Judgment Day (1991)
# 98514     607      589     4.0   963078960  Terminator 2: Judgment Day (1991)
# 98786     608      589     3.0  1117415154  Terminator 2: Judgment Day (1991)
# 99519     609      589     3.0   847220990  Terminator 2: Judgment Day (1991)
# 99573     610      589     5.0  1479542983  Terminator 2: Judgment Day (1991)
#
#               genres
# ...

# %%
distribution_data = merged_df[merged_df['title']=='Fight Club (1999)']
print(distribution_data)
# Out:
#        userId  movieId  rating   timestamp              title  \
# 192         1     2959     5.0   964983282  Fight Club (1999)
# 458         4     2959     2.0   945078528  Fight Club (1999)
# 1134       10     2959     0.5  1455356582  Fight Club (1999)
# 1479       15     2959     2.5  1510571747  Fight Club (1999)
# 1635       16     2959     3.5  1377476874  Fight Club (1999)
# ...       ...      ...     ...         ...                ...
# 95893     601     2959     5.0  1441639461  Fight Club (1999)
# 96788     603     2959     4.0   963176105  Fight Club (1999)
# 97835     606     2959     5.0  1171231517  Fight Club (1999)
# 99107     608     2959     5.0  1117336631  Fight Club (1999)
# 99699     610     2959     5.0  1479541966  Fight Club (1999)
#
#                             genres
# 192    Action|Crime|Drama|Thriller
# 458    Action|Crime|Drama|Thriller
# 1134   Action|Crime|Drama|Thriller
# 1479   Action|Crime|Drama|Thriller
# 1635   Action|Crime|Drama|Thriller
# ...

# %%
import matplotlib.pyplot as plt
plt.plot([i for i in range(0,218)],distribution_data['rating'], marker='o', linestyle='-', color='b')
plt.title('Line Chart of Values Over Time')
plt.xlabel('title')
plt.ylabel('rating')
plt.show()

# %%
rating1= distribution_data['rating'].tolist()

print(rating1)
# Out:
# [5.0, 2.0, 0.5, 2.5, 3.5, 4.5, 4.5, 5.0, 2.0, 3.5, 3.5, 4.0, 4.0, 3.0, 5.0, 2.0, 3.0, 4.5, 5.0, 5.0, 4.5, 4.5, 5.0, 4.5, 2.5, 4.5, 5.0, 3.5, 4.5, 5.0, 5.0, 5.0, 4.5, 5.0, 5.0, 4.5, 5.0, 4.0, 4.0, 5.0, 3.0, 5.0, 4.0, 5.0, 0.5, 4.0, 5.0, 3.0, 4.5, 4.5, 4.0, 4.5, 4.5, 5.0, 3.0, 4.0, 4.0, 3.0, 5.0, 5.0, 5.0, 5.0, 4.5, 5.0, 4.5, 4.5, 4.5, 1.5, 5.0, 3.5, 4.0, 5.0, 3.0, 4.5, 4.0, 5.0, 3.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 3.5, 4.5, 5.0, 4.0, 3.5, 3.0, 2.0, 4.5, 5.0, 5.0, 4.5, 4.5, 4.0, 0.5, 5.0, 5.0, 4.0, 4.0, 4.0, 5.0, 4.0, 4.0, 4.5, 3.5, 4.5, 4.5, 4.0, 4.0, 5.0, 3.5, 5.0, 4.0, 5.0, 4.5, 5.0, 4.5, 4.5, 4.5, 4.5, 4.5, 3.5, 4.0, 5.0, 5.0, 4.0, 4.5, 5.0, 4.0, 5.0, 3.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 4.0, 4.0, 4.5, 4.5, 4.0, 3.5, 4.0, 5.0, 5.0, 3.5, 4.5, 4.0, 5.0, 4.0, 4.5, 5.0, 5.0, 4.5, 3.5, 5.0, 4.0, 4.0, 4.0, 4.0, 4.5, 4.5, 5.0, 4.0, 4.5, 3.5, 5.0, 4.0, 3.5, 5.0, 5.0, 2.5, 5.0, 4.0, 4.5, 3.5, 4.0, 5.0, 5.0, 4.5, 5.0, 5.0, 5.0, 4.5, 4.5, 5.0, 4.0, 4.5, 4.
# ...

# %%
from collections import Counter
rating_counts = Counter(rating1)

# Print the counts
print("Rating Counts:")
for rating in sorted(rating_counts.keys(), reverse=True):
    print(f"Rating {rating}: {rating_counts[rating]}")
# Out:
# Rating Counts:
# Rating 5.0: 81
# Rating 4.5: 49
# Rating 4.0: 49
# Rating 3.5: 17
# Rating 3.0: 10
# Rating 2.5: 3
# Rating 2.0: 5
# Rating 1.5: 1
# Rating 0.5: 3

# %%
import matplotlib.pyplot as plt

# Ratings and their counts

counts = [rating_counts.get(r, 0) for r in rating1]

# Plotting the line chart
plt.figure(figsize=(10, 6))
plt.plot(rating1, counts, marker='o', linestyle='-', color='b')
plt.title('Ratings Distribution')
plt.xlabel('Rating')
plt.ylabel('Number of People')
plt.xticks(rating1)  # Ensure all rating points are shown on the x-axis
plt.grid(True)
plt.show()

# %%
aggregated_df = df.groupby('movieId').agg(
    count_ratings=('rating', 'count'),
    mean_rating=('rating', 'mean')
).reset_index()

# Print the result
print(aggregated_df)
# Out:
#       movieId  count_ratings  mean_rating
# 0           1            215     3.920930
# 1           2            110     3.431818
# 2           3             52     3.259615
# 3           4              7     2.357143
# 4           5             49     3.071429
# ...       ...            ...          ...
# 9719   193581              1     4.000000
# 9720   193583              1     3.500000
# 9721   193585              1     3.500000
# 9722   193587              1     3.500000
# 9723   193609              1     4.000000
#
# [9724 rows x 3 columns]

# %%
merged_df3 = pd.merge(df1, aggregated_df, on='movieId', how='inner')
print(merged_df3)
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  count_ratings  mean_rating
# 0     Adventure|Animation|Children|Comedy|Fantasy            215     3.920930
# 1                      Adventure|Children|Fantasy            110     3.431818
# ...

# %%
movies_50 = merged_df3[merged_df3['count_ratings'] > 50]
print(movies_50)
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  count_ratings  mean_rating
# 0     Adventure|Animation|Children|Comedy|Fantasy            215     3.920930
# 1                      Adventure|Children|Fantasy            110     3.431818
# 2                                  Comedy|Romance             52     3.259615
# ...

# %%
sorted_df = movies_50.sort_values(by='mean_rating', ascending=False)
sorted_df1=movies_50.sort_values(by='count_ratings',ascending=False)
print(sorted_df1)
# Out:
#       movieId                             title  \
# 314       356               Forrest Gump (1994)
# 277       318  Shawshank Redemption, The (1994)
# 257       296               Pulp Fiction (1994)
# 510       593  Silence of the Lambs, The (1991)
# 1938     2571                Matrix, The (1999)
# ...       ...                               ...
# 3147     4239                       Blow (2001)
# 3490     4776               Training Day (2001)
# 3539     4848           Mulholland Drive (2001)
# 118       145                   Bad Boys (1995)
# 1235     1645       The Devil's Advocate (1997)
#
#                                       genres  count_ratings  mean_rating
# 314                 Comedy|Drama|Romance|War            329     4.164134
# 277                              Crime|Drama            317     4.429022
# 257              Comedy|Crime|Drama|Thriller            307     4.197068
# 510                    Crime|Horror|Thriller            279     4.161290
# ...

# %%
def has_scifi(genres):
    return 'Sci-Fi' in genres.split('|')
scifi_df = sorted_df1[sorted_df1['genres'].apply(has_scifi)]
print(scifi_df)
# Out:
#       movieId                                              title  \
# 1938     2571                                 Matrix, The (1999)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 418       480                               Jurassic Park (1993)
# 507       589                  Terminator 2: Judgment Day (1991)
# 897      1196  Star Wars: Episode V - The Empire Strikes Back...
# ...       ...                                                ...
# 8673   122904                                    Deadpool (2016)
# 2028     2701                              Wild Wild West (1999)
# 144       172                             Johnny Mnemonic (1995)
# 559       673                                   Space Jam (1996)
# 6192    45499                       X-Men: The Last Stand (2006)
#
#                                                  genres  count_ratings  \
# 1938                             Action|Sci-Fi|Thriller            278
# ...

# %%
df3=pd.read_csv("C:/Users/pramo/Downloads/movie_data/links.csv")
print(df3)
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    # Convert IMDb ID to 7-digit format
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    
    # URL construction
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    
    # Request headers
    request_header = {
        'Content-Type': 'text/html; charset=UTF-8', 
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
        'Accept-Encoding': 'gzip, deflate, br'
    }
    
    # Send HTTP GET request
    response = requests.get(URL, headers=request_header)
    
    # Parse HTML response
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find IMDb rating
    imdb_rating = soup.find('span', attrs={'itemprop': 'ratingValue'})
    return new_id
    return imdb_rating
    #return imdb_rating.text if imdb_rating else np.nan

for imdb_id in imdb:
        rating = scrapper(imdb_id)
        print(f"IMDb Rating for ID {imdb_id}: {rating}")
# Out:
# IMDb Rating for ID 114709: 0114709
# IMDb Rating for ID 113497: 0113497
# IMDb Rating for ID 113228: 0113228
# IMDb Rating for ID 114885: 0114885
# IMDb Rating for ID 113041: 0113041
# IMDb Rating for ID 113277: 0113277
# IMDb Rating for ID 114319: 0114319
# IMDb Rating for ID 112302: 0112302
# IMDb Rating for ID 114576: 0114576
# IMDb Rating for ID 113189: 0113189
# IMDb Rating for ID 112346: 0112346
# IMDb Rating for ID 112896: 0112896
# IMDb Rating for ID 112453: 0112453
# IMDb Rating for ID 113987: 0113987
# IMDb Rating for ID 112760: 0112760
# IMDb Rating for ID 112641: 0112641
# IMDb Rating for ID 114388: 0114388
# IMDb Rating for ID 113101: 0113101
# IMDb Rating for ID 112281: 0112281
# IMDb Rating for ID 113845: 0113845
# IMDb Rating for ID 113161: 0113161
# IMDb Rating for ID 112722: 0112722
# IMDb Rating for ID 112401: 0112401
# IMDb Rating for ID 114168: 0114168
# IMDb Rating for ID 113627: 0113627
# IMDb Rating for ID 114057: 0114057
# IMDb Rating for ID 114011: 0114011
# ...

# %%
imdb=df3['imdbId'].tolist()

# %%
for imdb_id in imdb:
        rating = scrapper(imdb_id)
        print(f"IMDb Rating for ID {new_id}: {rating}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 for imdb_id in imdb:
#       2         rating = scrapper(imdb_id)
# ----> 3         print(f"IMDb Rating for ID {new_id}: {rating}")
#
# NameError: name 'new_id' is not defined

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import numpy as np

def scrapper1(imdbId):
    options = Options()
    options.add_argument("--headless")
    service = Service('path/to/chromedriver')  # Make sure to provide the correct path to chromedriver
    driver = webdriver.Chrome(service=service, options=options)
    
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    
    driver.get(URL)
    
    try:
        imdb_rating = driver.find_element(By.CSS_SELECTOR, 'span[itemprop="ratingValue"]')
        rating = imdb_rating.text
    except:
        rating = np.nan

    driver.quit()
    return rating

# %%
import requests
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {
        'Content-Type': 'text/html; charset=UTF-8', 
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
        'Accept-Encoding': 'gzip, deflate, br'
    }
    
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find IMDb rating
    imdb_rating_div = soup.find('div', attrs={'data-testid': 'hero-rating-bar__aggregate-rating__score'})
    if imdb_rating_div:
        rating_span = imdb_rating_div.find('span', class_='sc-eb51e184-1 ljxVSS')
        return rating_span.text if rating_span else 'Rating not found'
    return 'Rating not found'


ratings = []
for imdb_id in imdb:
    rating = scrapper(imdb_id)
    ratings.append((imdb_id, rating))
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:748, in HTTPResponse._error_catcher(self)
#     747 try:
# --> 748     yield
#     750 except SocketTimeout as e:
#     751     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     752     # there is yet no clean way to get at it from this context.
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:1209, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1208     break
# -> 1209 chunk = self._handle_chunk(amt)
#    1210 decoded = self._decode(
#    1211     chunk, decode_content=decode_content, flush_decoder=False
#    1212 )
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:1156, in HTTPResponse._handle_chunk(self, amt)
#    1155 returned_chunk = self._fp._safe_read(self.chunk_left)  # type: ignore[union-attr]
# ...

# %%
print(ratings)
# Out:
# [(114709, '8.3'), (113497, '7.1'), (113228, '6.7'), (114885, '6.0'), (113041, '6.1'), (113277, '8.3'), (114319, '6.3'), (112302, '5.5'), (114576, '5.8'), (113189, '7.2'), (112346, '6.8'), (112896, '5.8'), (112453, '7.1'), (113987, '7.1'), (112760, '5.7'), (112641, '8.2'), (114388, '7.7'), (113101, '6.7'), (112281, '6.4'), (113845, '5.7'), (113161, '6.9'), (112722, '6.6'), (112401, '6.3'), (114168, '6.6'), (113627, '7.5'), (114057, '6.8'), (114011, '6.8'), (114117, '7.7'), (112682, '7.5'), (115012, '7.1'), (112792, '6.5'), (114746, '8.0'), (112431, '6.9'), (112818, '7.5'), (113442, '5.9'), (112697, '6.9'), (112749, '6.8'), (114279, '7.3'), (112819, '6.9'), (114272, '6.6'), (113855, '5.8'), (114681, '6.8'), (113347, '6.3'), (114369, '8.6'), (114148, '6.7'), (114916, '6.5'), (114814, '8.5'), (113819, '7.0'), (110299, '7.4'), (112499, '5.5'), (113158, '6.5'), (113321, '6.6'), (110877, '7.8'), (113419, '6.0'), (116260, '6.2'), (113862, '7.3'), (116126, '6.5'), (118002, '5.3'), (115683, '4
# ...

# %%
#merged_df4 = pd.merge(df3, ratings, on='movieId', how='inner')
imdbdata=pd.DataFrame(ratings,columns=['imdbId','rating'])

print(imdbdata)
# Out:
#       imdbId rating
# 0     114709    8.3
# 1     113497    7.1
# 2     113228    6.7
# 3     114885    6.0
# 4     113041    6.1
# ...      ...    ...
# 1963  138510    6.2
# 1964  162973    7.5
# 1965  115669    7.7
# 1966  155388    7.3
# 1967   37913    7.9
#
# [1968 rows x 2 columns]

# %%
merged_df4 = pd.merge(imdbdata, df3, on='imdbId')
print(merged_df4)
# Out:
#       imdbId rating  movieId   tmdbId
# 0     114709    8.3        1    862.0
# 1     113497    7.1        2   8844.0
# 2     113228    6.7        3  15602.0
# 3     114885    6.0        4  31357.0
# 4     113041    6.1        5  11862.0
# ...      ...    ...      ...      ...
# 1963  138510    6.2     2606   6552.0
# 1964  162973    7.5     2607  24584.0
# 1965  115669    7.7     2609  25471.0
# 1966  155388    7.3     2611  28519.0
# 1967   37913    7.9     2612   3309.0
#
# [1968 rows x 4 columns]

# %%
largest_rating = merged_df4['rating'].tolist()
print(largest_rating)
for i in largest_rating:
    if i>=9.0:
      print(i)
# Out:
# ['8.3', '7.1', '6.7', '6.0', '6.1', '8.3', '6.3', '5.5', '5.8', '7.2', '6.8', '5.8', '7.1', '7.1', '5.7', '8.2', '7.7', '6.7', '6.4', '5.7', '6.9', '6.6', '6.3', '6.6', '7.5', '6.8', '6.8', '7.7', '7.5', '7.1', '6.5', '8.0', '6.9', '7.5', '5.9', '6.9', '6.8', '7.3', '6.9', '6.6', '5.8', '6.8', '6.3', '8.6', '6.7', '6.5', '8.5', '7.0', '7.4', '5.5', '6.5', '6.6', '7.8', '6.0', '6.2', '7.3', '6.5', '5.3', '4.4', '2.6', '6.4', '7.2', '7.2', '4.4', '6.7', '7.4', '6.1', '4.8', '6.3', '7.2', '6.3', '5.7', '7.6', '6.7', '7.4', '7.5', '6.8', '6.6', '5.4', '6.2', '6.3', '5.8', '4.6', '7.1', '6.1', '7.2', '8.1', '6.6', '6.2', '6.9', '3.8', '6.0', '7.0', '7.6', '7.2', '6.9', '7.0', '8.3', '8.2', '6.7', '6.1', '8.1', '7.0', '4.9', '4.7', '7.5', '5.6', '8.0', '6.7', '3.2', '7.1', '5.8', '5.3', '6.2', '5.9', '6.1', '7.2', '6.6', '6.8', '5.7', '7.3', '5.8', '6.8', '7.7', '6.9', '6.4', '5.4', '7.6', '6.5', '6.6', '5.9', '6.2', '6.9', '5.3', '7.3', '8.0', '7.1', '6.8', '7.6', '6.1', '6.0', '5.1', '6.
# ...

# %%
pd.set_option('display.max_rows', None)  # To display all rows
pd.set_option('display.max_columns', None)  # To display all columns

# Print the entire DataFrame
print(merged_df4)
# Out:
#       imdbId            rating  movieId    tmdbId
# 0     114709               8.3        1     862.0
# 1     113497               7.1        2    8844.0
# 2     113228               6.7        3   15602.0
# 3     114885               6.0        4   31357.0
# 4     113041               6.1        5   11862.0
# 5     113277               8.3        6     949.0
# 6     114319               6.3        7   11860.0
# 7     112302               5.5        8   45325.0
# 8     114576               5.8        9    9091.0
# 9     113189               7.2       10     710.0
# 10    112346               6.8       11    9087.0
# 11    112896               5.8       12   12110.0
# 12    112453               7.1       13   21032.0
# 13    113987               7.1       14   10858.0
# 14    112760               5.7       15    1408.0
# 15    112641               8.2       16     524.0
# 16    114388               7.7       17    4584.0
# 17    113101               6.7       18       5.0
# ...
